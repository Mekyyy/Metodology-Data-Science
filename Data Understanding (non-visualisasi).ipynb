# %% [markdown]
# #Install Kaggle

# %%
# !pip install -q kaggle

# %% [markdown]
# #Buat Directory

# %%
# !mkdir ~/.kaggle

# %% [markdown]
# #Copy File

# %%
# !cp kaggle.json ~/.kaggle

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# #Menunjukkan list dari kaggle

# %%
# !kaggle datasets list
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.6.11 / client 1.5.16)
# ref                                                           title                                            size  lastUpdated          downloadCount  voteCount  usabilityRating
# ------------------------------------------------------------  ----------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# sudarshan24byte/online-food-dataset                           Online Food Dataset                               3KB  2024-03-02 18:50:30          26590        522  0.9411765
# nbroad/gemma-rewrite-nbroad                                   gemma-rewrite-nbroad                              8MB  2024-03-03 04:52:39           1663        104  1.0
# lovishbansal123/adult-census-income                           Adult Census Income                             450KB  2024-04-12 08:18:30            489         23  1.0
# sukhmandeepsinghbrar/most-subscribed-youtube-channel          Most Subscribed YouTube Channel                   1KB  2024-04-10 20:33:05           1103         34  1.0
# sanyamgoyal401/customer-purchases-behaviour-dataset           Customer Purchases Behaviour Dataset              1MB  2024-04-06 18:42:01           1672         41  1.0
# startalks/pii-models                                          pii-models                                        1GB  2024-03-21 21:23:40            118         19  1.0
# fatemehmehrparvar/obesity-levels                              Obesity Levels                                   58KB  2024-04-07 16:28:30           1867         46  0.88235295
# sahirmaharajj/employee-salaries-analysis                      Employee Salaries Analysis                      101KB  2024-03-31 16:32:47           1592         48  1.0
# bhavikjikadara/student-study-performance                      Student Study Performance                         9KB  2024-03-07 06:14:09          12884        168  1.0
# soumyajitjalua/crop-datasets-for-all-indian-states-2010-2017  Crop Datasets for All Indian States: 2010-2017  305KB  2024-04-09 15:16:46            484         24  1.0
# sukhmandeepsinghbrar/housing-price-dataset                    Housing Price Dataset                           780KB  2024-04-04 19:45:43           1831         35  1.0
# divu2001/restaurant-order-data                                Restaurant Order Data                           426KB  2024-04-10 08:33:29            669         24  1.0
# willianoliveiragibin/worlds-wildlife                          world’s wildlife?                                92KB  2024-04-12 19:44:08            426         21  1.0
# sahirmaharajj/air-pollution-dataset                           Air Pollution Dataset                           213KB  2024-04-07 13:14:48           1242         39  1.0
# joshuanaude/effects-of-alcohol-on-student-performance         Effects of Alcohol on Student Performance.        9KB  2024-03-25 12:08:03           1627         34  1.0
# zubairmustafa/shopping-mall-customer-segmentation-data        Shopping Mall Customer Segmentation Data        426KB  2024-03-29 20:36:22            898         21  0.9411765
# mohdshahnawazaadil/credit-card-dataset                        Credit Card Dataset                              66MB  2024-04-02 00:04:05           1107         27  1.0
# sahilnbajaj/loans-data                                        Loans Data                                      213KB  2024-04-07 15:08:37           1110         29  1.0
# rushikeshdane20/global-trends-in-atmospheric-carbon-dioxide   Global Trends in Atmospheric CO2 Emission        20KB  2024-04-13 03:45:31            601         22  0.8235294
# sahirmaharajj/electric-vehicle-population-size-2024           Electric Vehicle Population by Country (2024)   275KB  2024-03-30 19:16:06           2329         62  1.0

# %% [markdown]
# #Download Dataset

# %%
# !kaggle datasets download -d 'shreyanshkhandelwal/goal-dataset-top-5-european-leagues'
# Out:
# Downloading goal-dataset-top-5-european-leagues.zip to /content
#   0% 0.00/174k [00:00<?, ?B/s]
# 100% 174k/174k [00:00<00:00, 86.9MB/s]

# %% [markdown]
# #Unzip

# %%
# !unzip goal-dataset-top-5-european-leagues.zip
# Out:
# Archive:  goal-dataset-top-5-european-leagues.zip
#   inflating: Bundesliga-goalScorer(20-21).csv
#   inflating: LaLiga-goalScorer(20-21).csv
#   inflating: Ligue_1-goalScorer(20-21).csv
#   inflating: Serie_A-goalScorer(20-21).csv
#   inflating: epl-goalScorer(20-21).csv

# %% [markdown]
# #Menampilkan data lewat pandas dan numpy

# %%
import pandas as pd
import numpy as np

# %%
path = "epl-goalScorer(20-21).csv"
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    Unnamed: 0    id      player_name  games  time  goals         xG  assists  \
# 0           0   647       Harry Kane     35  3097     23  22.174859       14
# 1           1  1250    Mohamed Salah     37  3085     22  20.250847        5
# 2           2  1228  Bruno Fernandes     37  3117     18  16.019454       12
# 3           3   453    Son Heung-Min     37  3139     17  11.023287       10
# 4           4   822  Patrick Bamford     38  3085     17  18.401863        7
#
#           xA  shots  key_passes  yellow_cards  red_cards position  \
# 0   7.577094    138          49             1          0        F
# 1   6.528526    126          55             0          0    F M S
# 2  11.474996    121          95             6          0      M S
# 3   9.512992     68          75             0          0    F M S
# 4   3.782247    107          30             3          0      F S
#
#           team_title  npg       npxG    xGChain  xGBuildup
# 0          Tottenham   19  19.130183  24.995648   4.451257
# 1          Liverpool   16  15.683834  28.968234   9.800236
# 2  Manchester United    9   8.407840  26.911412  11.932285
# 3          Tottenham   16  10.262118  20.671916   6.608751
# 4              Leeds   15  16.879525  23.394953   4.131796

# %%
print(df.dtypes)
# Out:
# Unnamed: 0        int64
# id                int64
# player_name      object
# games             int64
# time              int64
# goals             int64
# xG              float64
# assists           int64
# xA              float64
# shots             int64
# key_passes        int64
# yellow_cards      int64
# red_cards         int64
# position         object
# team_title       object
# npg               int64
# npxG            float64
# xGChain         float64
# xGBuildup       float64
# dtype: object

# %%
df_noid = df.iloc[:,2:]
df_noid
# Out:
#                 player_name  games  time  goals         xG  assists  \
# 0                Harry Kane     35  3097     23  22.174859       14
# 1             Mohamed Salah     37  3085     22  20.250847        5
# 2           Bruno Fernandes     37  3117     18  16.019454       12
# 3             Son Heung-Min     37  3139     17  11.023287       10
# 4           Patrick Bamford     38  3085     17  18.401863        7
# ..                      ...    ...   ...    ...        ...      ...
# 517  Jaden Philogene-Bidace      1     1      0   0.000000        0
# 518         Gaetano Berardi      2   113      0   0.074761        0
# 519          Anthony Elanga      1    67      0   0.000000        0
# 520             Femi Seriki      1     1      0   0.000000        0
# 521         Tyrese Francois      1    13      0   0.000000        0
#
#             xA  shots  key_passes  yellow_cards  red_cards position  \
# 0     7.577094    138          49             1          0        F
# 1     6.528526    126          55             0          0    F M S
# 2    11.474996    121          95             6          0      M S
# 3     9.512992     68          75             0          0    F M S
# 4     3.782247    107          30             3          0      F S
# ..         ...    ...         ...           ...        ...      ...
# 517   0.000000      0           0             0          0        S
# 518   0.000000      1           0             0          0      D S
# 519   0.000000      0           0             0          0        M
# 520   0.000000      0           0             0          0        S
# 521   0.000000      0           0             0          0        S
#
#             team_title  npg       npxG    xGChain  xGBuildup
# 0            Tottenham   19  19.130183  24.995648   4.451257
# 1            Liverpool   16  15.683834  28.968234   9.800236
# 2    Manchester United    9   8.407840  26.911412  11.932285
# 3            Tottenham   16  10.262118  20.671916   6.608751
# 4                Leeds   15  16.879525  23.394953   4.131796
# ..                 ...  ...        ...        ...        ...
# 517        Aston Villa    0   0.000000   0.056044   0.056044
# 518              Leeds    0   0.074761   0.231278   0.231278
# 519  Manchester United    0   0.000000   0.000000   0.000000
# 520   Sheffield United    0   0.000000   0.000000   0.000000
# 521             Fulham    0   0.000000   0.000000   0.000000
#
# [522 rows x 17 columns]

# %%
df_noid.describe()
# Out:
#             games         time       goals          xG     assists  \
# count  522.000000   522.000000  522.000000  522.000000  522.000000
# mean    19.643678  1420.068966    1.862069    2.000806    1.289272
# std     11.619836  1031.604819    3.338851    3.317946    2.083350
# min      1.000000     1.000000    0.000000    0.000000    0.000000
# 25%     10.000000   470.250000    0.000000    0.074668    0.000000
# 50%     21.000000  1342.000000    1.000000    0.737295    0.000000
# 75%     30.000000  2319.000000    2.000000    2.053378    2.000000
# max     38.000000  3420.000000   23.000000   22.174859   14.000000
#
#                xA       shots  key_passes  yellow_cards   red_cards  \
# count  522.000000  522.000000  522.000000    522.000000  522.000000
# mean     1.376029   17.379310   12.963602      2.061303    0.091954
# std      1.886510   21.572664   16.164361      2.203661    0.295800
# min      0.000000    0.000000    0.000000      0.000000    0.000000
# 25%      0.049245    2.000000    1.000000      0.000000    0.000000
# 50%      0.691122   10.000000    7.000000      2.000000    0.000000
# 75%      2.050509   23.750000   19.000000      3.000000    0.000000
# max     11.474996  138.000000   95.000000     12.000000    2.000000
#
#               npg        npxG     xGChain   xGBuildup
# count  522.000000  522.000000  522.000000  522.000000
# mean     1.668582    1.821450    5.663368    3.455060
# std      2.909929    2.931176    5.600249    3.376584
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.074668    1.191391    0.720353
# 50%      0.500000    0.715585    4.252738    2.656397
# 75%      2.000000    1.945799    8.308002    5.254647
# max     19.000000   19.130183   28.968234   18.323006
